# %%
import pandas as pd

# %%
#data=pd.read_csv('train.csv')
data=pd.read_csv('validation.csv')

# %%
data.head()
# Out:
#       번호   연령  성별         상황키워드  신체질환 감정_대분류 감정_소분류  \
# 0  23093   청년  여성    진로, 취업, 직장  해당없음     분노   툴툴대는
# 1  32848  청소년  남성          가족관계  해당없음     슬픔    비통한
# 2  35590  청소년  남성      학교폭력/따돌림  해당없음     불안  조심스러운
# 3    169   청년  남성    진로, 취업, 직장  해당없음     당황   죄책감의
# 4  38435   중년  여성  재정, 은퇴, 노후준비  해당없음     분노  노여워하는
#
#                                               사람문장1  \
# 0                                   요즘 부모님과 많이 부딪혀.
# 1                          엄마가 결국 집을 나갔어. 너무 너무 슬퍼.
# 2                    학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.
# 3  이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.
# 4                 남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.
#
#                                         시스템응답1  \
# 0                                어떤 일로 부딪히시나요?
# 1  어머니께서 집을 나가셨다니 정말 슬프셨겠어요. 좀 더 자세히 얘기해주시겠어요?
# 2                   용기 있는 행동을 하셨네요. 마음이 어떠셨나요?
# 3      팀장님이 부탁하신 업무를 잘못 처리하셔서 많이 당황하시고 놀라셨겠어요.
# 4                                 많이 화가 나시겠어요.
#
# ...

# %%
data=data.fillna("")

# %%
data["text"] = data["사람문장1"] + "," + data["시스템응답1"]+ "," +data["사람문장2"] + "," + data["시스템응답2"]+ "," +data["사람문장3"] + "," + data["시스템응답3"]+ "," +data["사람문장4"] + "," + data["시스템응답4"]
train = data.drop({"사람문장1","시스템응답1","사람문장2","시스템응답2","사람문장3","시스템응답3","사람문장4","시스템응답4","번호","연령","성별","상황키워드","신체질환","감정_대분류"}, axis=1)

# %%
train["emotion"] = train["감정_소분류"]

# %%
train = train.drop({"감정_소분류"}, axis=1)
train.head()
# Out:
#                                                 text emotion
# 0  요즘 부모님과 많이 부딪혀.,어떤 일로 부딪히시나요?,난 하고 싶은 일이 있는데 부...    툴툴대는
# 1  엄마가 결국 집을 나갔어. 너무 너무 슬퍼.,어머니께서 집을 나가셨다니 정말 슬프셨...     비통한
# 2  학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.,용기 있는 행동을 하셨네요....   조심스러운
# 3  이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이...    죄책감의
# 4  남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.,많이 화가 나시겠어요....   노여워하는

# %%
#train.to_csv("train_after.csv")
train.to_csv("validation_after.csv")
